# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
empty = np.load('dataset/empty_depth.npy')

# %%
plt.imshow(empty)

# %%
d = np.load('dataset/1/d.npy')

# %%
plt.imshow(d)

# %%
d[d==3] = empty[d==3]

# %%
plt.imshow(d)

# %%
d[0,0]
# Out:
# 3.0
